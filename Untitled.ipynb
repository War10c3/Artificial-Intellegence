# %% [markdown]
# # House Price Prediction: EDA
#
# ## Introduction
#
# #### Dataset statistics:
# #### Price listing of houses: 21614
# #### average number of bedrooms: 3
# #### average number of floors: 1.5
# #### years built range: 1900<x<2014
# #### average sqloft: 12768
#
#
# ## Data Fields Explanation
#
# #### The House Price Prediction dataset consists of 21614 entries. This dataset consists of a single CSV file, kc_house_data.csv. The columns in the table are:
#
#
# #### Id - Unique row number
# #### date- date of registration
# #### bedroom- no of bedrooms
# #### bathrooms- no of bathrooms
# #### sq_living- area of living room
# #### sqlot- area of lot
# #### floors- number of floors
# #### waterfront
# #### view
# #### condition
# #### grade
# #### sqft_above
# #### sqft_basement- area of basement
# #### yr_built-
# #### yr_renovate
# #### zipcode
# #### latitude
# #### longitude
# #### sqft_living

# %%
#Let's import pandas to read the csv file.
import pandas as pd
df = pd.read_csv("kc_house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
print(df.keys())
df.shape
### Note: We have 21 features and 21613 data points.
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')
# (21613, 21)

# %%
#Lets check for missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
#no missing values

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure()
sns.countplot(x='bedrooms', data=df, palette='RdBu')
plt.xlabel('bedrooms (bedrooms)')
plt.show()

# %%
#copying the original dataframe to 'temp_df'.
temp_df = df[['id','price','condition', 'sqft_lot15', 'bedrooms','grade']].copy()

#Adding new features to dataframe.
temp_df["Sentiments"] = temp_df["condition"].apply(lambda condition: "positive" if condition > 3 else \
                                              ("negative" if condition < 3 else "not defined"))
temp_df["Usefulness"] = (temp_df["sqft_lot15"]/temp_df["price"]).apply\
(lambda n: ">75%" if n > 0.75 else ("<25%" if n < 0.25 else ("25-75%" if n >= 0.25 and\
                                                                        n <= 0.75 else "useless")))

temp_df.loc[temp_df.price == 0, 'Usefulness'] = ["useless"]
# Removing all rows where 'Score' is equal to 3
#temp_df = temp_df[temp_df.Score != 3]
#Lets now observe the shape of our new dataframe.
temp_df.shape
# Out:
# (21613, 8)

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 8 columns):
# id            21613 non-null int64
# price         21613 non-null float64
# condition     21613 non-null int64
# sqft_lot15    21613 non-null int64
# bedrooms      21613 non-null int64
# grade         21613 non-null int64
# Sentiments    21613 non-null object
# Usefulness    21613 non-null object
# dtypes: float64(1), int64(5), object(2)
# memory usage: 1.3+ MB

# %%
sns.countplot(x='Sentiments', order=["positive", "negative"], data=temp_df, palette='RdBu')
plt.xlabel('Sentiments')
plt.show()
temp_df.Sentiments.value_counts()
# Out:
# not defined    14031
# positive        7380
# negative         202
# Name: Sentiments, dtype: int64

# %%
pos = temp_df.loc[temp_df['Sentiments'] == 'positive']
pos = pos[0:25000]

neg = temp_df.loc[temp_df['Sentiments'] == 'negative']
neg = neg[0:25000]

# %%
temp_df.Usefulness.value_counts()
# Out:
# <25%      21342
# 25-75%      251
# >75%         20
# Name: Usefulness, dtype: int64

# %%
sns.countplot(x='Usefulness', order=['useless', '>75%', '25-75%', '<25%'], data=temp_df, palette='RdBu')
plt.xlabel('Usefulness')
plt.show()

# %%
sns.violinplot(x='Usefulness', y='price', order=[">75%", "<25%"], \
               data=temp_df, palette='RdBu')
plt.ylim(-50, 400)
plt.show()

# %% [markdown]
# # Conclusion
# ### a. Positive homes are very common.
# ### b. Positive homes are costly.
# ### c. costly reviews are larger.
# ### d. Quality and condition of the houses are related.
# ### e. better the condition more the chance to be selected
